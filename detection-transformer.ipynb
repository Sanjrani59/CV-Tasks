# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.5 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 4.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.2 MB/s eta 0:00:00:00:0100:01
# ...

# %%
from ultralytics import YOLO

# Load pretrained RT-DETR (official HF version)
model = YOLO('rtdetr-l.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
# !pip install roboflow
def download_dataset():
    from roboflow import Roboflow
    rf = Roboflow(api_key="QHr9qKdWagsf1TvMIUq1")
    project = rf.workspace("sanjrani").project("canola-2-leaf")
    version = project.version(2)
    dataset = version.download("yolov12")
                

# Uncomment to download dataset
dataset_path = download_dataset()
print(f"Dataset downloaded to: {dataset_path}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 35.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 90.9 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
results = model.train(
    data='/kaggle/working/Canola-Cotyledon-4/data.yaml',
    epochs=30,             # Increase training epochs
    batch=4,
    imgsz=1024,              # Higher resolution
    workers=2,
    lr0=0.01,               # Initial learning rate
    lrf=0.01,               # Final learning rate fraction (end of cosine schedule)
    momentum=0.937,         # Momentum for optimizer
    weight_decay=0.0005,    # Helps regularization
    warmup_epochs=3,        # Warmup for stable initial convergence
    augment=True,
    patience=7,  # controls both early stopping & LR scheduler patience
    optimizer='AdamW',
    close_mosaic=10,  # Disable heavy mosaic after 10 epochs (optional)
    # degrees=5,  # Rotation augmentation
    # translate=0.03,  # Shift augmentation
    # scale=0.1,  # Zoom augmentation
    # shear=2,  # Shear augmentation
    # perspective=0.0003,  # Perspective warping
    # flipud=0.00,  # Vertical flip probability
    # hsv_h=0.01,  # Hue augmentation
    # # hsv_s=0.2,  # Saturation augmentation
    # # #hsv_v=0.2  # Brightness augmentation
)

# %%
# ==========================================================
# STEP 6 — Load best model for prediction
# ==========================================================
best_model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# %%
import os
import cv2
import random
import shutil
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from ultralytics import YOLO
from PIL import Image

# %%
val_dir = f'{work_dir}/images/val'
val_images = os.listdir(val_dir)
sample_images = random.sample(val_images, 30)

for img_file in sample_images:
    img_path = os.path.join(val_dir, img_file)
    results = best_model.predict(source=img_path, conf=0.4, save=False)

    res_plotted = results[0].plot()  # visualize predictions
    plt.figure(figsize=(10, 10))
    plt.imshow(res_plotted)
    plt.axis('off')
    plt.title(img_file)
    plt.show()

# %%
from ultralytics import YOLO

# Load trained model from the training folder
model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# %%
results = model.predict(
    source='/kaggle/input/canola-images-test/DJI_20250520110657_0210_D.JPG',  # your actual image path
    imgsz=1024,                  # image size used in training
    conf=0.25,                  # confidence threshold
    save=True                   # saves the output with bounding boxes
)

# %%
from IPython.display import Image, display

display(Image(filename='/kaggle/working/runs/detect/predict/flood1.jpg'))

# %%
results = model.predict(
    source='/kaggle/input/floodvictim/flood2.png',  # your actual image path
    imgsz=960,                  # image size used in training
    conf=0.25,                  # confidence threshold
    save=True                   # saves the output with bounding boxes
)

# %%
from IPython.display import Image, display

display(Image(filename='/kaggle/working/runs/detect/predict/flood2.jpg'))

# %%
results = model.predict(
    source='/kaggle/input/floodvictim/flood3.png',  # your actual image path
    imgsz=960,                  # image size used in training
    conf=0.25,                  # confidence threshold
    save=True                   # saves the output with bounding boxes
)

# %%
from IPython.display import Image, display

display(Image(filename='/kaggle/working/runs/detect/predict/flood3.jpg'))

# %%
results = model.predict(
    source='/kaggle/input/floodvictim/flood4.png',  # your actual image path
    imgsz=960,                  # image size used in training
    conf=0.25,                  # confidence threshold
    save=True                   # saves the output with bounding boxes
)

# %%
from IPython.display import Image, display

display(Image(filename='/kaggle/working/runs/detect/predict/flood4.jpg'))

# %%
results = model.predict(
    source='/kaggle/input/floodvictim/flood5.png',  # your actual image path
    imgsz=960,                  # image size used in training
    conf=0.25,                  # confidence threshold
    save=True                   # saves the output with bounding boxes
)

# %%
from IPython.display import Image, display

display(Image(filename='/kaggle/working/runs/detect/predict/flood5.jpg'))
